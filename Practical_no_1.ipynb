# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasang-06/Machine_Learning_College/blob/main/Practical_no_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Introduction to Python Programming, Setting up the Environment, Basic
# Syntax.

# %% [markdown]
# Program 1:- Input and Output statements in Python by taking User Input

# %%
name = input("Enter your name: ")
print("Hello,", name, "! Welcome!")
# Out:
# Enter your name: Prashiki
# Hello, Prashiki ! Welcome!

# %% [markdown]
# Program 2:- Python Indentation

# %%
#Example for identation error
if 6 > 3:
print("Six is greater than three")
# Out:
#   File "/tmp/ipython-input-3232675793.py", line 3
#     print("Six is greater than three")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
if 6 > 5:
  print("Six is greater than three")
# Out:
# Six is greater than three

# %% [markdown]
# Program 3:- Python Variables with Exceptional Handling

# %%
# Example for exceptional handling
my_var = 40
_var = 50
var2 = 60
print(my_var)
print(_var)
print(var2)
# Out:
# 40
# 50
# 60

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are eligible to drive.")
else:
    print("You are not eligible to drive.")
# Out:
# Enter your age: 21
# You are eligible to drive.

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(num, "is an even number.")
else:
    print(num, "is an odd number.")
# Out:
# Enter a number: 6
# 6 is an even number.

# %%
#print which one larger or if they are equal.

num
